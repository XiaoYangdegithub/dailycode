# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import make_hastie_10_2  # 生成12000行数据
data, target = make_hastie_10_2()
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=123)
X_train.shape, X_test.shape
y_train # y中有负值不能应用在xgboost中
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)  # 解决y的取值问题

# %%
# 对比模型
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
import time

# %%
clf1 = LogisticRegression()
clf2 = RandomForestClassifier()
clf3 = AdaBoostClassifier()
clf4 = GradientBoostingClassifier()
clf5 = XGBClassifier()


for clf, label in zip([clf1, clf2, clf3, clf4, clf5], [
        'Logistic Regression', 'Random Forest', 'AdaBoost', 'GBDT', 'XGBoost'
]):
    start = time.time()
    scores = cross_val_score(clf, X_train, y_train, scoring='accuracy', cv=5)
    end = time.time()
    running_time = end - start
    print("Accuracy: %0.8f (+/- %0.2f),耗时%0.2f秒。模型名称[%s]" %
          (scores.mean(), scores.std(), running_time, label))
# Out:
# Accuracy: 0.48977778 (+/- 0.00),耗时0.06秒。模型名称[Logistic Regression]
# Accuracy: 0.88555556 (+/- 0.00),耗时9.17秒。模型名称[Random Forest]
# Accuracy: 0.87655556 (+/- 0.00),耗时1.75秒。模型名称[AdaBoost]
# Accuracy: 0.91477778 (+/- 0.00),耗时7.77秒。模型名称[GBDT]
# Accuracy: 0.92866667 (+/- 0.00),耗时5.85秒。模型名称[XGBoost]

# %%
# 使用xgboost
import xgboost as xgb
import time

start_time = time.time()
xgb_train = xgb.DMatrix(X_train, y_train)
xgb_test = xgb.DMatrix(X_test, label=y_test)
params = {
    'booster': 'gbtree',
    'eta': 0.007,    # lr
    'min_child_weight': 3,
    'max_depth': 6,  
    'gamma': 0.1,  
    'subsample': 0.7,  
    'colsample_bytree': 0.7,  
    'lambda': 2, 
    'seed': 1000,  
}
plst = list(params.items())
num_rounds = 500  
watchlist = [(xgb_train, 'train'), (xgb_test, 'val')]

# %%
# 进行模型训练
model = xgb.train(
    plst,
    xgb_train,
    num_rounds,
    watchlist,
    early_stopping_rounds=100,
)
print("best best_ntree_limit", model.best_ntree_limit)
y_pred = model.predict(xgb_test, ntree_limit=model.best_ntree_limit)
print('error=%f' %
      (sum(1
           for i in range(len(y_pred)) if int(y_pred[i] > 0.5) != y_test[i]) /
       float(len(y_pred))))
cost_time = time.time() - start_time
print("xgboost success!", '\n', "cost time:", cost_time, "(s)......")
# Out:
# [0]	train-rmse:0.49936	val-rmse:1.12260
# [1]	train-rmse:0.49871	val-rmse:1.12210
# [2]	train-rmse:0.49810	val-rmse:1.12162
# [3]	train-rmse:0.49747	val-rmse:1.12109
# [4]	train-rmse:0.49681	val-rmse:1.12055
# [5]	train-rmse:0.49616	val-rmse:1.12006
# [6]	train-rmse:0.49551	val-rmse:1.11958
# [7]	train-rmse:0.49488	val-rmse:1.11910
# [8]	train-rmse:0.49426	val-rmse:1.11861
# [9]	train-rmse:0.49361	val-rmse:1.11808
# [10]	train-rmse:0.49299	val-rmse:1.11759
# [11]	train-rmse:0.49237	val-rmse:1.11710
# [12]	train-rmse:0.49173	val-rmse:1.11662
# [13]	train-rmse:0.49111	val-rmse:1.11610
# [14]	train-rmse:0.49048	val-rmse:1.11564
# [15]	train-rmse:0.48987	val-rmse:1.11514
# [16]	train-rmse:0.48924	val-rmse:1.11465
# [17]	train-rmse:0.48860	val-rmse:1.11413
# [18]	train-rmse:0.48801	val-rmse:1.11366
# [19]	train-rmse:0.48742	val-rmse:1.11317
# [20]	train-rmse:0.48682	val-rmse:1.11269
# [21]	train-rmse:0.48626	val-rmse:1.11223
# [22]	train-rmse:0.48567	val-rmse:1.11178
# [23]	train-rmse:0.48508	val-rmse:1.11132
# [24]	train-rmse:0.48449	val-rmse:1.11087
# [25]	train-rmse:0.48386	val-rmse:1.11038
# [26]	train-rmse:0.48328	val-rmse:1.10989
# [27]	train-rmse:0.48269	val-rmse:1.10945
# [28]	train-rmse:0.48211	val-rmse:1.10902
# [29]	train-rmse:0.48152	val-rmse:1.10855
# [30]	train-rmse:0.48094	val-rmse:1.10814
# [31]	train-rmse:0.48037	val-rmse:1.10768
# [32]	train-rmse:0.47979	val-rmse:1.10721
# [33]	train-rmse:0.47920	val-rmse:1.10675
# [34]	train-rmse:0.47861	val-rmse:1.10630
# [35]	train-rmse:0.47804	val-rmse:1.10585
# [36]	train-rmse:0.47748	val-rmse:1.10541
# [37]	train-rmse:0.47691	val-rmse:1.10496
# [38]	train-rmse:0.47638	val-rmse:1.10455
# [39]	train-rmse:0.47581	val-rmse:1.10411
# [40]	train-rmse:0.47524	val-rmse:1.10366
# [41]	train-rmse:0.47466	val-rmse:1.10325
# [42]	train-rmse:0.47409	val-rmse:1.10282
# [43]	train-rmse:0.47353	val-rmse:1.10240
# [44]	train-rmse:0.47295	val-rmse:1.10195
# [45]	train-rmse:0.47241	val-rmse:1.10151
# [46]	train-rmse:0.47183	val-rmse:1.10102
# [47]	train-rmse:0.47129	val-rmse:1.10061
# [48]	train-rmse:0.47067	val-rmse:1.10018
# [49]	train-rmse:0.47008	val-rmse:1.09972
# [50]	train-rmse:0.46953	val-rmse:1.09928
# [51]	train-rmse:0.46898	val-rmse:1.09886
# [52]	train-rmse:0.46841	val-rmse:1.09841
# [53]	train-rmse:0.46783	val-rmse:1.09797
# [54]	train-rmse:0.46729	val-rmse:1.09754
# [55]	train-rmse:0.46676	val-rmse:1.09713
# [56]	train-rmse:0.46621	val-rmse:1.09671
# [57]	train-rmse:0.46569	val-rmse:1.09629
# [58]	train-rmse:0.46514	val-rmse:1.09585
# [59]	train-rmse:0.46457	val-rmse:1.09538
# [60]	train-rmse:0.46405	val-rmse:1.09498
# [61]	train-rmse:0.46352	val-rmse:1.09457
# [62]	train-rmse:0.46297	val-rmse:1.09413
# [63]	train-rmse:0.46243	val-rmse:1.09373
# [64]	train-rmse:0.46190	val-rmse:1.09331
# [65]	train-rmse:0.46135	val-rmse:1.09288
# [66]	train-rmse:0.46080	val-rmse:1.09242
# [67]	train-rmse:0.46026	val-rmse:1.09201
# [68]	train-rmse:0.45975	val-rmse:1.09164
# [69]	train-rmse:0.45924	val-rmse:1.09125
# [70]	train-rmse:0.45872	val-rmse:1.09084
# [71]	train-rmse:0.45819	val-rmse:1.09041
# [72]	train-rmse:0.45765	val-rmse:1.08997
# [73]	train-rmse:0.45714	val-rmse:1.08957
# [74]	train-rmse:0.45660	val-rmse:1.08911
# [75]	train-rmse:0.45609	val-rmse:1.08871
# [76]	train-rmse:0.45554	val-rmse:1.08828
# [77]	train-rmse:0.45503	val-rmse:1.08790
# [78]	train-rmse:0.45452	val-rmse:1.08749
# [79]	train-rmse:0.45400	val-rmse:1.08704
# [80]	train-rmse:0.45348	val-rmse:1.08663
# [81]	train-rmse:0.45296	val-rmse:1.08619
# [82]	train-rmse:0.45242	val-rmse:1.08576
# [83]	train-rmse:0.45190	val-rmse:1.08534
# [84]	train-rmse:0.45138	val-rmse:1.08493
# [85]	train-rmse:0.45090	val-rmse:1.08455
# [86]	train-rmse:0.45039	val-rmse:1.08413
# [87]	train-rmse:0.44989	val-rmse:1.08374
# [88]	train-rmse:0.44939	val-rmse:1.08333
# [89]	train-rmse:0.44886	val-rmse:1.08294
# [90]	train-rmse:0.44839	val-rmse:1.08259
# [91]	train-rmse:0.44790	val-rmse:1.08219
# [92]	train-rmse:0.44740	val-rmse:1.08179
# [93]	train-rmse:0.44692	val-rmse:1.08141
# [94]	train-rmse:0.44642	val-rmse:1.08101
# [95]	train-rmse:0.44591	val-rmse:1.08063
# [96]	train-rmse:0.44543	val-rmse:1.08026
# [97]	train-rmse:0.44495	val-rmse:1.07986
# [98]	train-rmse:0.44448	val-rmse:1.07949
# [99]	train-rmse:0.44396	val-rmse:1.07908
# [100]	train-rmse:0.44342	val-rmse:1.07864
# [101]	train-rmse:0.44293	val-rmse:1.07828
# [102]	train-rmse:0.44243	val-rmse:1.07787
# [103]	train-rmse:0.44195	val-rmse:1.07749
# [104]	train-rmse:0.44147	val-rmse:1.07710
# [105]	train-rmse:0.44098	val-rmse:1.07674
# [106]	train-rmse:0.44049	val-rmse:1.07634
# [107]	train-rmse:0.44002	val-rmse:1.07598
# [108]	train-rmse:0.43955	val-rmse:1.07559
# [109]	train-rmse:0.43906	val-rmse:1.07519
# [110]	train-rmse:0.43858	val-rmse:1.07479
# [111]	train-rmse:0.43810	val-rmse:1.07441
# [112]	train-rmse:0.43762	val-rmse:1.07401
# [113]	train-rmse:0.43715	val-rmse:1.07363
# [114]	train-rmse:0.43668	val-rmse:1.07325
# [115]	train-rmse:0.43620	val-rmse:1.07287
# [116]	train-rmse:0.43575	val-rmse:1.07251
# [117]	train-rmse:0.43528	val-rmse:1.07213
# [118]	train-rmse:0.43480	val-rmse:1.07173
# [119]	train-rmse:0.43434	val-rmse:1.07136
# [120]	train-rmse:0.43385	val-rmse:1.07095
# [121]	train-rmse:0.43339	val-rmse:1.07056
# [122]	train-rmse:0.43296	val-rmse:1.07020
# [123]	train-rmse:0.43249	val-rmse:1.06982
# [124]	train-rmse:0.43203	val-rmse:1.06945
# [125]	train-rmse:0.43156	val-rmse:1.06905
# [126]	train-rmse:0.43110	val-rmse:1.06868
# [127]	train-rmse:0.43062	val-rmse:1.06830
# [128]	train-rmse:0.43016	val-rmse:1.06791
# [129]	train-rmse:0.42969	val-rmse:1.06752
# [130]	train-rmse:0.42925	val-rmse:1.06714
# [131]	train-rmse:0.42879	val-rmse:1.06674
# [132]	train-rmse:0.42834	val-rmse:1.06635
# [133]	train-rmse:0.42788	val-rmse:1.06596
# [134]	train-rmse:0.42741	val-rmse:1.06558
# [135]	train-rmse:0.42694	val-rmse:1.06519
# [136]	train-rmse:0.42650	val-rmse:1.06483
# [137]	train-rmse:0.42607	val-rmse:1.06450
# [138]	train-rmse:0.42563	val-rmse:1.06413
# [139]	train-rmse:0.42520	val-rmse:1.06381
# [140]	train-rmse:0.42475	val-rmse:1.06345
# [141]	train-rmse:0.42431	val-rmse:1.06308
# [142]	train-rmse:0.42387	val-rmse:1.06268
# [143]	train-rmse:0.42343	val-rmse:1.06233
# [144]	train-rmse:0.42300	val-rmse:1.06200
# [145]	train-rmse:0.42258	val-rmse:1.06165
# [146]	train-rmse:0.42217	val-rmse:1.06131
# [147]	train-rmse:0.42173	val-rmse:1.06096
# [148]	train-rmse:0.42130	val-rmse:1.06060
# [149]	train-rmse:0.42088	val-rmse:1.06025
# [150]	train-rmse:0.42042	val-rmse:1.05987
# [151]	train-rmse:0.42000	val-rmse:1.05953
# [152]	train-rmse:0.41954	val-rmse:1.05918
# [153]	train-rmse:0.41909	val-rmse:1.05881
# [154]	train-rmse:0.41865	val-rmse:1.05844
# [155]	train-rmse:0.41826	val-rmse:1.05813
# [156]	train-rmse:0.41785	val-rmse:1.05779
# [157]	train-rmse:0.41743	val-rmse:1.05744
# [158]	train-rmse:0.41698	val-rmse:1.05709
# [159]	train-rmse:0.41652	val-rmse:1.05676
# [160]	train-rmse:0.41611	val-rmse:1.05642
# [161]	train-rmse:0.41568	val-rmse:1.05607
# [162]	train-rmse:0.41527	val-rmse:1.05576
# [163]	train-rmse:0.41488	val-rmse:1.05539
# [164]	train-rmse:0.41443	val-rmse:1.05502
# [165]	train-rmse:0.41398	val-rmse:1.05468
# [166]	train-rmse:0.41356	val-rmse:1.05432
# [167]	train-rmse:0.41312	val-rmse:1.05395
# [168]	train-rmse:0.41268	val-rmse:1.05358
# [169]	train-rmse:0.41227	val-rmse:1.05324
# [170]	train-rmse:0.41186	val-rmse:1.05291
# [171]	train-rmse:0.41145	val-rmse:1.05256
# [172]	train-rmse:0.41102	val-rmse:1.05222
# [173]	train-rmse:0.41065	val-rmse:1.05191
# [174]	train-rmse:0.41024	val-rmse:1.05158
# [175]	train-rmse:0.40982	val-rmse:1.05122
# [176]	train-rmse:0.40940	val-rmse:1.05091
# [177]	train-rmse:0.40896	val-rmse:1.05058
# [178]	train-rmse:0.40857	val-rmse:1.05025
# [179]	train-rmse:0.40815	val-rmse:1.04991
# [180]	train-rmse:0.40775	val-rmse:1.04962
# [181]	train-rmse:0.40734	val-rmse:1.04925
# [182]	train-rmse:0.40695	val-rmse:1.04893
# [183]	train-rmse:0.40655	val-rmse:1.04860
# [184]	train-rmse:0.40612	val-rmse:1.04823
# [185]	train-rmse:0.40570	val-rmse:1.04789
# [186]	train-rmse:0.40528	val-rmse:1.04758
# [187]	train-rmse:0.40491	val-rmse:1.04726
# [188]	train-rmse:0.40451	val-rmse:1.04694
# [189]	train-rmse:0.40409	val-rmse:1.04655
# [190]	train-rmse:0.40368	val-rmse:1.04623
# [191]	train-rmse:0.40326	val-rmse:1.04591
# [192]	train-rmse:0.40289	val-rmse:1.04560
# [193]	train-rmse:0.40248	val-rmse:1.04526
# [194]	train-rmse:0.40209	val-rmse:1.04496
# [195]	train-rmse:0.40170	val-rmse:1.04464
# [196]	train-rmse:0.40131	val-rmse:1.04430
# [197]	train-rmse:0.40091	val-rmse:1.04395
# [198]	train-rmse:0.40051	val-rmse:1.04360
# [199]	train-rmse:0.40011	val-rmse:1.04327
# [200]	train-rmse:0.39971	val-rmse:1.04292
# [201]	train-rmse:0.39930	val-rmse:1.04263
# [202]	train-rmse:0.39892	val-rmse:1.04231
# [203]	train-rmse:0.39854	val-rmse:1.04198
# [204]	train-rmse:0.39819	val-rmse:1.04169
# [205]	train-rmse:0.39780	val-rmse:1.04135
# [206]	train-rmse:0.39741	val-rmse:1.04103
# [207]	train-rmse:0.39702	val-rmse:1.04069
# [208]	train-rmse:0.39664	val-rmse:1.04036
# [209]	train-rmse:0.39624	val-rmse:1.04005
# [210]	train-rmse:0.39583	val-rmse:1.03972
# [211]	train-rmse:0.39541	val-rmse:1.03939
# [212]	train-rmse:0.39505	val-rmse:1.03909
# [213]	train-rmse:0.39467	val-rmse:1.03878
# [214]	train-rmse:0.39432	val-rmse:1.03850
# [215]	train-rmse:0.39395	val-rmse:1.03818
# [216]	train-rmse:0.39358	val-rmse:1.03786
# [217]	train-rmse:0.39317	val-rmse:1.03754
# [218]	train-rmse:0.39281	val-rmse:1.03725
# [219]	train-rmse:0.39241	val-rmse:1.03693
# [220]	train-rmse:0.39205	val-rmse:1.03662
# [221]	train-rmse:0.39169	val-rmse:1.03633
# [222]	train-rmse:0.39131	val-rmse:1.03601
# [223]	train-rmse:0.39095	val-rmse:1.03570
# [224]	train-rmse:0.39059	val-rmse:1.03538
# [225]	train-rmse:0.39022	val-rmse:1.03507
# [226]	train-rmse:0.38985	val-rmse:1.03479
# [227]	train-rmse:0.38949	val-rmse:1.03446
# [228]	train-rmse:0.38915	val-rmse:1.03417
# [229]	train-rmse:0.38878	val-rmse:1.03386
# [230]	train-rmse:0.38844	val-rmse:1.03357
# [231]	train-rmse:0.38809	val-rmse:1.03329
# [232]	train-rmse:0.38774	val-rmse:1.03298
# [233]	train-rmse:0.38738	val-rmse:1.03268
# [234]	train-rmse:0.38704	val-rmse:1.03239
# [235]	train-rmse:0.38667	val-rmse:1.03208
# [236]	train-rmse:0.38631	val-rmse:1.03177
# [237]	train-rmse:0.38595	val-rmse:1.03144
# [238]	train-rmse:0.38557	val-rmse:1.03113
# [239]	train-rmse:0.38521	val-rmse:1.03083
# [240]	train-rmse:0.38486	val-rmse:1.03054
# [241]	train-rmse:0.38451	val-rmse:1.03027
# [242]	train-rmse:0.38417	val-rmse:1.03002
# [243]	train-rmse:0.38381	val-rmse:1.02972
# [244]	train-rmse:0.38344	val-rmse:1.02940
# [245]	train-rmse:0.38308	val-rmse:1.02910
# [246]	train-rmse:0.38272	val-rmse:1.02878
# [247]	train-rmse:0.38235	val-rmse:1.02846
# [248]	train-rmse:0.38203	val-rmse:1.02820
# [249]	train-rmse:0.38168	val-rmse:1.02789
# [250]	train-rmse:0.38134	val-rmse:1.02760
# [251]	train-rmse:0.38099	val-rmse:1.02732
# [252]	train-rmse:0.38065	val-rmse:1.02703
# [253]	train-rmse:0.38031	val-rmse:1.02677
# [254]	train-rmse:0.37996	val-rmse:1.02648
# [255]	train-rmse:0.37960	val-rmse:1.02621
# [256]	train-rmse:0.37926	val-rmse:1.02592
# [257]	train-rmse:0.37890	val-rmse:1.02562
# [258]	train-rmse:0.37855	val-rmse:1.02532
# [259]	train-rmse:0.37820	val-rmse:1.02502
# [260]	train-rmse:0.37786	val-rmse:1.02474
# [261]	train-rmse:0.37756	val-rmse:1.02447
# [262]	train-rmse:0.37720	val-rmse:1.02416
# [263]	train-rmse:0.37688	val-rmse:1.02391
# [264]	train-rmse:0.37655	val-rmse:1.02365
# [265]	train-rmse:0.37620	val-rmse:1.02339
# [266]	train-rmse:0.37586	val-rmse:1.02312
# [267]	train-rmse:0.37551	val-rmse:1.02285
# [268]	train-rmse:0.37519	val-rmse:1.02258
# [269]	train-rmse:0.37485	val-rmse:1.02231
# [270]	train-rmse:0.37450	val-rmse:1.02204
# [271]	train-rmse:0.37415	val-rmse:1.02177
# [272]	train-rmse:0.37383	val-rmse:1.02149
# [273]	train-rmse:0.37350	val-rmse:1.02123
# [274]	train-rmse:0.37320	val-rmse:1.02097
# [275]	train-rmse:0.37286	val-rmse:1.02066
# [276]	train-rmse:0.37251	val-rmse:1.02039
# [277]	train-rmse:0.37220	val-rmse:1.02013
# [278]	train-rmse:0.37188	val-rmse:1.01986
# [279]	train-rmse:0.37158	val-rmse:1.01958
# [280]	train-rmse:0.37124	val-rmse:1.01932
# [281]	train-rmse:0.37090	val-rmse:1.01905
# [282]	train-rmse:0.37059	val-rmse:1.01874
# [283]	train-rmse:0.37023	val-rmse:1.01846
# [284]	train-rmse:0.36992	val-rmse:1.01821
# [285]	train-rmse:0.36960	val-rmse:1.01796
# [286]	train-rmse:0.36927	val-rmse:1.01768
# [287]	train-rmse:0.36896	val-rmse:1.01742
# [288]	train-rmse:0.36865	val-rmse:1.01716
# [289]	train-rmse:0.36835	val-rmse:1.01689
# [290]	train-rmse:0.36802	val-rmse:1.01662
# [291]	train-rmse:0.36770	val-rmse:1.01634
# [292]	train-rmse:0.36738	val-rmse:1.01604
# [293]	train-rmse:0.36706	val-rmse:1.01578
# [294]	train-rmse:0.36673	val-rmse:1.01550
# [295]	train-rmse:0.36640	val-rmse:1.01523
# [296]	train-rmse:0.36609	val-rmse:1.01496
# [297]	train-rmse:0.36577	val-rmse:1.01470
# [298]	train-rmse:0.36546	val-rmse:1.01444
# [299]	train-rmse:0.36513	val-rmse:1.01417
# [300]	train-rmse:0.36483	val-rmse:1.01391
# [301]	train-rmse:0.36452	val-rmse:1.01363
# [302]	train-rmse:0.36420	val-rmse:1.01335
# [303]	train-rmse:0.36390	val-rmse:1.01309
# [304]	train-rmse:0.36357	val-rmse:1.01282
# [305]	train-rmse:0.36324	val-rmse:1.01257
# [306]	train-rmse:0.36292	val-rmse:1.01229
# [307]	train-rmse:0.36262	val-rmse:1.01204
# [308]	train-rmse:0.36232	val-rmse:1.01179
# [309]	train-rmse:0.36201	val-rmse:1.01152
# [310]	train-rmse:0.36170	val-rmse:1.01126
# [311]	train-rmse:0.36140	val-rmse:1.01096
# [312]	train-rmse:0.36108	val-rmse:1.01071
# [313]	train-rmse:0.36076	val-rmse:1.01048
# [314]	train-rmse:0.36046	val-rmse:1.01025
# [315]	train-rmse:0.36017	val-rmse:1.01002
# [316]	train-rmse:0.35986	val-rmse:1.00978
# [317]	train-rmse:0.35954	val-rmse:1.00953
# [318]	train-rmse:0.35925	val-rmse:1.00928
# [319]	train-rmse:0.35893	val-rmse:1.00901
# [320]	train-rmse:0.35864	val-rmse:1.00875
# [321]	train-rmse:0.35835	val-rmse:1.00850
# [322]	train-rmse:0.35806	val-rmse:1.00826
# [323]	train-rmse:0.35776	val-rmse:1.00797
# [324]	train-rmse:0.35745	val-rmse:1.00772
# [325]	train-rmse:0.35715	val-rmse:1.00747
# [326]	train-rmse:0.35684	val-rmse:1.00721
# [327]	train-rmse:0.35654	val-rmse:1.00697
# [328]	train-rmse:0.35623	val-rmse:1.00674
# [329]	train-rmse:0.35592	val-rmse:1.00650
# [330]	train-rmse:0.35562	val-rmse:1.00624
# [331]	train-rmse:0.35533	val-rmse:1.00600
# [332]	train-rmse:0.35504	val-rmse:1.00575
# [333]	train-rmse:0.35477	val-rmse:1.00553
# [334]	train-rmse:0.35446	val-rmse:1.00527
# [335]	train-rmse:0.35418	val-rmse:1.00504
# [336]	train-rmse:0.35389	val-rmse:1.00479
# [337]	train-rmse:0.35362	val-rmse:1.00454
# [338]	train-rmse:0.35332	val-rmse:1.00432
# [339]	train-rmse:0.35304	val-rmse:1.00405
# [340]	train-rmse:0.35274	val-rmse:1.00382
# [341]	train-rmse:0.35245	val-rmse:1.00360
# [342]	train-rmse:0.35215	val-rmse:1.00334
# [343]	train-rmse:0.35185	val-rmse:1.00309
# [344]	train-rmse:0.35158	val-rmse:1.00287
# [345]	train-rmse:0.35131	val-rmse:1.00263
# [346]	train-rmse:0.35100	val-rmse:1.00239
# [347]	train-rmse:0.35072	val-rmse:1.00214
# [348]	train-rmse:0.35046	val-rmse:1.00193
# [349]	train-rmse:0.35017	val-rmse:1.00170
# [350]	train-rmse:0.34984	val-rmse:1.00149
# [351]	train-rmse:0.34958	val-rmse:1.00123
# [352]	train-rmse:0.34930	val-rmse:1.00099
# [353]	train-rmse:0.34902	val-rmse:1.00074
# [354]	train-rmse:0.34873	val-rmse:1.00051
# [355]	train-rmse:0.34844	val-rmse:1.00028
# [356]	train-rmse:0.34819	val-rmse:1.00006
# [357]	train-rmse:0.34792	val-rmse:0.99984
# [358]	train-rmse:0.34765	val-rmse:0.99960
# [359]	train-rmse:0.34739	val-rmse:0.99934
# [360]	train-rmse:0.34711	val-rmse:0.99911
# [361]	train-rmse:0.34683	val-rmse:0.99888
# [362]	train-rmse:0.34656	val-rmse:0.99867
# [363]	train-rmse:0.34629	val-rmse:0.99846
# [364]	train-rmse:0.34603	val-rmse:0.99824
# [365]	train-rmse:0.34575	val-rmse:0.99800
# [366]	train-rmse:0.34549	val-rmse:0.99777
# [367]	train-rmse:0.34518	val-rmse:0.99752
# [368]	train-rmse:0.34490	val-rmse:0.99727
# [369]	train-rmse:0.34464	val-rmse:0.99705
# [370]	train-rmse:0.34437	val-rmse:0.99684
# [371]	train-rmse:0.34409	val-rmse:0.99659
# [372]	train-rmse:0.34383	val-rmse:0.99637
# [373]	train-rmse:0.34356	val-rmse:0.99612
# [374]	train-rmse:0.34329	val-rmse:0.99587
# [375]	train-rmse:0.34299	val-rmse:0.99564
# [376]	train-rmse:0.34273	val-rmse:0.99543
# [377]	train-rmse:0.34246	val-rmse:0.99519
# [378]	train-rmse:0.34220	val-rmse:0.99496
# [379]	train-rmse:0.34192	val-rmse:0.99471
# [380]	train-rmse:0.34168	val-rmse:0.99448
# [381]	train-rmse:0.34143	val-rmse:0.99426
# [382]	train-rmse:0.34116	val-rmse:0.99404
# [383]	train-rmse:0.34091	val-rmse:0.99379
# [384]	train-rmse:0.34066	val-rmse:0.99359
# [385]	train-rmse:0.34040	val-rmse:0.99338
# [386]	train-rmse:0.34015	val-rmse:0.99315
# [387]	train-rmse:0.33991	val-rmse:0.99292
# [388]	train-rmse:0.33967	val-rmse:0.99272
# [389]	train-rmse:0.33940	val-rmse:0.99248
# [390]	train-rmse:0.33913	val-rmse:0.99224
# [391]	train-rmse:0.33888	val-rmse:0.99205
# [392]	train-rmse:0.33861	val-rmse:0.99180
# [393]	train-rmse:0.33834	val-rmse:0.99157
# [394]	train-rmse:0.33809	val-rmse:0.99135
# [395]	train-rmse:0.33783	val-rmse:0.99112
# [396]	train-rmse:0.33757	val-rmse:0.99088
# [397]	train-rmse:0.33731	val-rmse:0.99068
# [398]	train-rmse:0.33707	val-rmse:0.99046
# [399]	train-rmse:0.33684	val-rmse:0.99025
# [400]	train-rmse:0.33658	val-rmse:0.99003
# [401]	train-rmse:0.33629	val-rmse:0.98981
# [402]	train-rmse:0.33606	val-rmse:0.98961
# [403]	train-rmse:0.33582	val-rmse:0.98940
# [404]	train-rmse:0.33556	val-rmse:0.98919
# [405]	train-rmse:0.33529	val-rmse:0.98898
# [406]	train-rmse:0.33502	val-rmse:0.98877
# [407]	train-rmse:0.33476	val-rmse:0.98855
# [408]	train-rmse:0.33452	val-rmse:0.98834
# [409]	train-rmse:0.33427	val-rmse:0.98813
# [410]	train-rmse:0.33400	val-rmse:0.98791
# [411]	train-rmse:0.33374	val-rmse:0.98769
# [412]	train-rmse:0.33349	val-rmse:0.98750
# [413]	train-rmse:0.33324	val-rmse:0.98728
# [414]	train-rmse:0.33300	val-rmse:0.98708
# [415]	train-rmse:0.33276	val-rmse:0.98687
# [416]	train-rmse:0.33251	val-rmse:0.98665
# [417]	train-rmse:0.33226	val-rmse:0.98643
# [418]	train-rmse:0.33206	val-rmse:0.98624
# [419]	train-rmse:0.33181	val-rmse:0.98604
# [420]	train-rmse:0.33157	val-rmse:0.98581
# [421]	train-rmse:0.33133	val-rmse:0.98560
# [422]	train-rmse:0.33109	val-rmse:0.98539
# [423]	train-rmse:0.33084	val-rmse:0.98517
# [424]	train-rmse:0.33058	val-rmse:0.98495
# [425]	train-rmse:0.33035	val-rmse:0.98476
# [426]	train-rmse:0.33009	val-rmse:0.98456
# [427]	train-rmse:0.32985	val-rmse:0.98437
# [428]	train-rmse:0.32961	val-rmse:0.98416
# [429]	train-rmse:0.32935	val-rmse:0.98396
# [430]	train-rmse:0.32914	val-rmse:0.98377
# [431]	train-rmse:0.32894	val-rmse:0.98359
# [432]	train-rmse:0.32868	val-rmse:0.98338
# [433]	train-rmse:0.32844	val-rmse:0.98319
# [434]	train-rmse:0.32821	val-rmse:0.98298
# [435]	train-rmse:0.32797	val-rmse:0.98278
# [436]	train-rmse:0.32775	val-rmse:0.98258
# [437]	train-rmse:0.32750	val-rmse:0.98237
# [438]	train-rmse:0.32728	val-rmse:0.98218
# [439]	train-rmse:0.32707	val-rmse:0.98198
# [440]	train-rmse:0.32684	val-rmse:0.98179
# [441]	train-rmse:0.32661	val-rmse:0.98158
# [442]	train-rmse:0.32636	val-rmse:0.98137
# [443]	train-rmse:0.32612	val-rmse:0.98114
# [444]	train-rmse:0.32587	val-rmse:0.98095
# [445]	train-rmse:0.32564	val-rmse:0.98076
# [446]	train-rmse:0.32541	val-rmse:0.98058
# [447]	train-rmse:0.32518	val-rmse:0.98039
# [448]	train-rmse:0.32494	val-rmse:0.98019
# [449]	train-rmse:0.32472	val-rmse:0.98001
# [450]	train-rmse:0.32449	val-rmse:0.97980
# [451]	train-rmse:0.32426	val-rmse:0.97961
# [452]	train-rmse:0.32401	val-rmse:0.97941
# [453]	train-rmse:0.32377	val-rmse:0.97923
# [454]	train-rmse:0.32354	val-rmse:0.97906
# [455]	train-rmse:0.32333	val-rmse:0.97885
# [456]	train-rmse:0.32309	val-rmse:0.97864
# [457]	train-rmse:0.32286	val-rmse:0.97843
# [458]	train-rmse:0.32265	val-rmse:0.97826
# [459]	train-rmse:0.32243	val-rmse:0.97810
# [460]	train-rmse:0.32222	val-rmse:0.97791
# [461]	train-rmse:0.32202	val-rmse:0.97772
# [462]	train-rmse:0.32181	val-rmse:0.97755
# [463]	train-rmse:0.32158	val-rmse:0.97736
# [464]	train-rmse:0.32137	val-rmse:0.97717
# [465]	train-rmse:0.32117	val-rmse:0.97701
# [466]	train-rmse:0.32096	val-rmse:0.97686
# [467]	train-rmse:0.32074	val-rmse:0.97669
# [468]	train-rmse:0.32051	val-rmse:0.97650
# [469]	train-rmse:0.32027	val-rmse:0.97631
# [470]	train-rmse:0.32003	val-rmse:0.97612
# [471]	train-rmse:0.31981	val-rmse:0.97594
# [472]	train-rmse:0.31958	val-rmse:0.97576
# [473]	train-rmse:0.31935	val-rmse:0.97557
# [474]	train-rmse:0.31916	val-rmse:0.97541
# [475]	train-rmse:0.31896	val-rmse:0.97520
# [476]	train-rmse:0.31874	val-rmse:0.97501
# [477]	train-rmse:0.31853	val-rmse:0.97480
# [478]	train-rmse:0.31831	val-rmse:0.97462
# [479]	train-rmse:0.31809	val-rmse:0.97443
# [480]	train-rmse:0.31788	val-rmse:0.97425
# [481]	train-rmse:0.31766	val-rmse:0.97408
# [482]	train-rmse:0.31745	val-rmse:0.97390
# [483]	train-rmse:0.31723	val-rmse:0.97373
# [484]	train-rmse:0.31702	val-rmse:0.97353
# [485]	train-rmse:0.31681	val-rmse:0.97336
# [486]	train-rmse:0.31661	val-rmse:0.97321
# [487]	train-rmse:0.31638	val-rmse:0.97302
# [488]	train-rmse:0.31618	val-rmse:0.97283
# [489]	train-rmse:0.31598	val-rmse:0.97265
# [490]	train-rmse:0.31577	val-rmse:0.97246
# [491]	train-rmse:0.31558	val-rmse:0.97228
# [492]	train-rmse:0.31538	val-rmse:0.97212
# [493]	train-rmse:0.31518	val-rmse:0.97195
# [494]	train-rmse:0.31496	val-rmse:0.97173
# [495]	train-rmse:0.31476	val-rmse:0.97156
# [496]	train-rmse:0.31456	val-rmse:0.97138
# [497]	train-rmse:0.31436	val-rmse:0.97122
# [498]	train-rmse:0.31412	val-rmse:0.97106
# [499]	train-rmse:0.31393	val-rmse:0.97087
# best best_ntree_limit 500
# error=0.557667
# xgboost success!
#  cost time: 72.77107882499695 (s)......

# %%
# 使用sklearn实现xgboost
from sklearn.model_selection import train_test_split
from sklearn import metrics
from xgboost import XGBClassifier

clf = XGBClassifier(
    learning_rate=0.7,
    min_child_weight=1,
    max_depth=6,
    gamma=0,
    subsample=1,
    max_delta_step=0,
    colsample_bytree=1,
    reg_lambda=1,
    n_estimators=100,
    seed=1000)
clf.fit(X_train, y_train)
y_true, y_pred = y_test, clf.predict(X_test) 
print('Accuracy : %.4g' % metrics.accuracy_score(y_true, y_pred))  # 为什么准确率这么低
# Out:
# Accuracy : 0.478
